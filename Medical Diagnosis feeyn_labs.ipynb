# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\DATA SCIENCE\FeynnLabs_Intern\ML Medical Diagonsis\Medical_Diagnosis.csv")

# %%
df.head()
# Out:
#    colored_sputum  cough  fever  headache class
# 0            0.70   1.70   4.10      1.70  cold
# 1            0.38   3.22   5.20      3.21  cold
# 2            0.38   1.22   3.70      3.11  cold
# 3            0.36   3.06   3.19      2.64  cold
# 4            0.46   3.16   2.79      2.94  cold

# %%
df.shape
# Out:
# (1633, 5)

# %%
df.isnull().sum()
# Out:
# colored_sputum    2
# cough             4
# fever             4
# headache          3
# class             0
# dtype: int64

# %%
df.describe()
# Out:
#        colored_sputum        cough        fever     headache
# count     1631.000000  1629.000000  1629.000000  1630.000000
# mean         4.034408     5.837716     8.200147     5.218669
# std          2.629871     2.551540     2.077712     3.232034
# min          0.000000     1.000000     1.100000     1.000000
# 25%          1.670000     3.520000     8.000000     2.492500
# 50%          2.950000     6.460000     8.740000     3.610000
# 75%          6.665000     7.780000     9.490000     8.510000
# max          8.520000    10.640000    11.240000    11.930000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1633 entries, 0 to 1632
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   colored_sputum  1631 non-null   float64
#  1   cough           1629 non-null   float64
#  2   fever           1629 non-null   float64
#  3   headache        1630 non-null   float64
#  4   class           1633 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 63.9+ KB

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# colored_sputum    0
# cough             0
# fever             0
# headache          0
# class             0
# dtype: int64

# %%
df.describe()
# Out:
#        colored_sputum        cough        fever     headache
# count     1620.000000  1620.000000  1620.000000  1620.000000
# mean         4.034204     5.836914     8.194883     5.207636
# std          2.629283     2.553928     2.080724     3.231637
# min          0.000000     1.000000     1.100000     1.000000
# 25%          1.670000     3.520000     8.000000     2.470000
# 50%          2.950000     6.460000     8.740000     3.600000
# 75%          6.660000     7.780000     9.490000     8.510000
# max          8.520000    10.640000    11.140000    11.930000

# %%
df.columns
# Out:
# Index(['colored_sputum', 'cough', 'fever', 'headache', 'class'], dtype='object')

# %%
df.corr()
# Out:
#                 colored_sputum     cough     fever  headache
# colored_sputum        1.000000  0.757932  0.607555 -0.421251
# cough                 0.757932  1.000000  0.662710 -0.173477
# fever                 0.607555  0.662710  1.000000  0.112840
# headache             -0.421251 -0.173477  0.112840  1.000000

# %%
sns.pairplot(df)

# %%
corrmat = df.corr()
df1 = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
A = sns.heatmap(df[df1].corr(),annot = True,)

# %%
df.head()
# Out:
#    colored_sputum  cough  fever  headache class
# 0            0.70   1.70   4.10      1.70  cold
# 1            0.38   3.22   5.20      3.21  cold
# 2            0.38   1.22   3.70      3.11  cold
# 3            0.36   3.06   3.19      2.64  cold
# 4            0.46   3.16   2.79      2.94  cold

# %%
sns.countplot(x = 'class',data = df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x = 'colored_sputum',data = df)
# Out:
# <AxesSubplot:xlabel='colored_sputum', ylabel='count'>

# %%
sns.countplot(x = 'cough',data = df)
# Out:
# <AxesSubplot:xlabel='cough', ylabel='count'>

# %%
sns.countplot(x = 'fever',data = df)
# Out:
# <AxesSubplot:xlabel='fever', ylabel='count'>

# %%
sns.countplot(x = 'headache',data = df)
# Out:
# <AxesSubplot:xlabel='headache', ylabel='count'>

# %%
#dist=df.hist(figsize=(15,15))
dist = df.hist(figsize=(20,20))

# %%
plt.figure(figsize = (20,10))
plt.subplot(121)
plt.title("Paitent Distrbutuion Plot")
sns.distplot(df.colored_sputum)

plt.subplot(122)
plt.title("Spread")
sns.boxplot(y = df.colored_sputum)
plt.show()
# Out:
# C:\Users\pares\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize = (20,10))
plt.subplot(121)
plt.title("Paitent Distrbutuion Plot")
sns.distplot(df.cough)

plt.subplot(122)
plt.title("Spread")
sns.boxplot(y = df.cough)
plt.show()
# Out:
# C:\Users\pares\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize = (20,10))
plt.subplot(121)
plt.title("Paitent Distrbutuion Plot")
sns.distplot(df.fever)

plt.subplot(122)
plt.title("Spread")
sns.boxplot(y = df.fever)
plt.show()
# Out:
# C:\Users\pares\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize = (20,10))
plt.subplot(121)
plt.title("Paitent Distrbutuion Plot")
sns.distplot(df.headache)

plt.subplot(122)
plt.title("Spread")
sns.boxplot(y = df.headache)
plt.show()
# Out:
# C:\Users\pares\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.linear_model import LinearRegression

# %%
df = df.drop(['class'],axis = 1)

# %%
df.head()
# Out:
#    colored_sputum  cough  fever  headache
# 0            0.70   1.70   4.10      1.70
# 1            0.38   3.22   5.20      3.21
# 2            0.38   1.22   3.70      3.11
# 3            0.36   3.06   3.19      2.64
# 4            0.46   3.16   2.79      2.94

# %%
#y_train = df_train.pop('price')
#X_train = df_train
y = df.pop('colored_sputum')
x = df

# %%
x.head()
# Out:
#    cough  fever  headache
# 0   1.70   4.10      1.70
# 1   3.22   5.20      3.21
# 2   1.22   3.70      3.11
# 3   3.06   3.19      2.64
# 4   3.16   2.79      2.94

# %%
y.head()
# Out:
# 0    0.70
# 1    0.38
# 2    0.38
# 3    0.36
# 4    0.46
# Name: colored_sputum, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
r_sq = model.score(x,y)
print(f"coefficient of determination:{r_sq}")
# Out:
# coefficient of determination:0.7202478223939126

# %%
print(f"intercept:{model.intercept_}")
print(f"slope:{model.coef_}")
# Out:
# intercept:-0.696773642718961
# slope:[ 0.47950795  0.43172785 -0.30836032]

# %%
y_pred = model.predict(x)
print(f"predicted responce:{y_pred}")
# Out:
# predicted responce:[1.36426153 2.10239017 0.52661853 ... 6.37565643 6.88321968 6.13034099]

# %%
x_pred = model.predict(x)
print(f"predicted responce:{x_pred}")
# Out:
# predicted responce:[1.36426153 2.10239017 0.52661853 ... 6.37565643 6.88321968 6.13034099]

# %%
#sns.distplot(y_test-predictions)
sns.distplot(y_pred,)
# Out:
# C:\Users\pares\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
#plt.scatter(y_test,predictions)
plt.scatter(y,y_pred)
